# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
os.listdir('.')
# os.chdir('drive/My Drive/Colab_Test/Dataset/Regression')
# Out:
# ['winequality-white.csv', 'bottle.csv', 'housing.csv', 'auto.csv']

# %%
dataset = pd.read_csv('bottle.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset.describe()
# Out:
#              Cst_Cnt        Btl_Cnt  ...        pH2        pH1
# count  864863.000000  864863.000000  ...  10.000000  84.000000
# mean    17138.790958  432432.000000  ...   7.948570   7.910983
# std     10240.949817  249664.587267  ...   0.021216   0.077666
# min         1.000000       1.000000  ...   7.923100   7.618300
# 25%      8269.000000  216216.500000  ...   7.931475   7.898675
# 50%     16848.000000  432432.000000  ...   7.946650   7.928850
# 75%     26557.000000  648647.500000  ...   7.963300   7.955100
# max     34404.000000  864863.000000  ...   7.988300   8.047700
#
# [8 rows x 70 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               853900 non-null  float64
#  6   Salnty               817509 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               812174 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               853900 non-null  float64
# ...

# %%
avg_0 = dataset['T_degC'].astype('float').mean(axis=0)
avg_1 = dataset['Salnty'].astype('float').mean(axis=0)
avg_2 = dataset['STheta'].astype('float').mean(axis=0)
avg_3 = dataset['T_prec'].astype('float').mean(axis=0)
avg_4 = dataset['S_prec'].astype('float').mean(axis=0)
avg_5 = dataset['NH3q'].astype('float').mean(axis=0)
avg_6 = dataset['C14A1q'].astype('float').mean(axis=0)
avg_7 = dataset['C14A2q'].astype('float').mean(axis=0)
avg_8 = dataset['DarkAq'].astype('float').mean(axis=0)
avg_9 = dataset['MeanAq'].astype('float').mean(axis=0)
avg_10 = dataset['R_TEMP'].astype('float').mean(axis=0)
avg_11 = dataset['R_POTEMP'].astype('float').mean(axis=0)
avg_12 = dataset['R_SALINITY'].astype('float').mean(axis=0)
avg_13 = dataset['R_SIGMA'].astype('float').mean(axis=0)
avg_14 = dataset['R_SVA'].astype('float').mean(axis=0)
avg_15 = dataset['R_DYNHT'].astype('float').mean(axis=0)

# %%
dataset['T_degC'].replace(np.nan, avg_0, inplace=True)
dataset['Salnty'].replace(np.nan, avg_1, inplace=True)
dataset['STheta'].replace(np.nan, avg_2, inplace=True)
dataset['T_prec'].replace(np.nan, avg_3, inplace=True)
dataset['S_prec'].replace(np.nan, avg_4, inplace=True)
dataset['NH3q'].replace(np.nan, avg_5, inplace=True)
dataset['C14A1q'].replace(np.nan, avg_6, inplace=True)
dataset['C14A2q'].replace(np.nan, avg_7, inplace=True)
dataset['DarkAq'].replace(np.nan, avg_8, inplace=True)
dataset['MeanAq'].replace(np.nan, avg_9, inplace=True)
dataset['R_TEMP'].replace(np.nan, avg_10, inplace=True)
dataset['R_POTEMP'].replace(np.nan, avg_11, inplace=True)
dataset['R_SALINITY'].replace(np.nan, avg_12, inplace=True)
dataset['R_SIGMA'].replace(np.nan, avg_13, inplace=True)
dataset['R_SVA'].replace(np.nan, avg_14, inplace=True)
dataset['R_DYNHT'].replace(np.nan, avg_15, inplace=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               864863 non-null  float64
#  6   Salnty               864863 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               864863 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               864863 non-null  float64
# ...

# %%
dataset.drop(['O2ml_L','O2Sat','Oxy_µmol/Kg','BtlNum','T_qual','S_qual','O_qual','SThtaq','O2Satq','ChlorA','Chlqua','Phaeop','Phaqua','PO4uM','PO4q','SiO3uM','SiO3qu','NO2uM','NO2q','NO3uM','NO3q','NH3uM','C14As1','C14A1p','C14As2','C14A2p','DarkAs','DarkAp','MeanAs','MeanAp'], axis = 1, inplace= True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               864863 non-null  float64
#  6   Salnty               864863 non-null  float64
#  7   STheta               864863 non-null  float64
#  8   RecInd               864863 non-null  int64
#  9   T_prec               864863 non-null  float64
#  10  S_prec               864863 non-null  float64
#  11  P_qual               673755 non-null  float64
#  12  NH3q                 864863 non-null  float64
#  13  C14A1q               864863 non-null  float64
# ...

# %%
dataset.drop(['LightP','R_O2','R_O2Sat','R_SIO3','R_PO4','R_NO3','R_NO2','R_NH4','R_CHLA','R_PHAEO','R_SAMP','DIC1','DIC2','TA1','TA2','pH2','pH1'], axis = 1, inplace=True )
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               864863 non-null  float64
#  6   Salnty               864863 non-null  float64
#  7   STheta               864863 non-null  float64
#  8   RecInd               864863 non-null  int64
#  9   T_prec               864863 non-null  float64
#  10  S_prec               864863 non-null  float64
#  11  P_qual               673755 non-null  float64
#  12  NH3q                 864863 non-null  float64
#  13  C14A1q               864863 non-null  float64
# ...

# %%
# dataset.drop(['Cst_Cnt','Btl_Cnt','Sta_ID','Depth_ID','NH3q','C14A1q','C14A2q','DarkAq','MeanAq',], axis = 1, inplace=True )
dataset.drop(['T_prec','S_prec','P_qual','IncTim','DIC Quality Comment'], axis = 1, inplace=True )
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Depthm      864863 non-null  int64
#  1   T_degC      864863 non-null  float64
#  2   Salnty      864863 non-null  float64
#  3   STheta      864863 non-null  float64
#  4   RecInd      864863 non-null  int64
#  5   R_Depth     864863 non-null  float64
#  6   R_TEMP      864863 non-null  float64
#  7   R_POTEMP    864863 non-null  float64
#  8   R_SALINITY  864863 non-null  float64
#  9   R_SIGMA     864863 non-null  float64
#  10  R_SVA       864863 non-null  float64
#  11  R_DYNHT     864863 non-null  float64
#  12  R_PRES      864863 non-null  int64
# dtypes: float64(10), int64(3)
# memory usage: 85.8 MB

# %%
dataset.corr()['T_degC']
# Out:
# Depthm       -0.678628
# T_degC        1.000000
# Salnty       -0.489967
# STheta       -0.804295
# RecInd       -0.066060
# R_Depth      -0.678626
# R_TEMP        1.000000
# R_POTEMP      0.973582
# R_SALINITY   -0.488706
# R_SIGMA      -0.836170
# R_SVA         0.935155
# R_DYNHT      -0.774224
# R_PRES       -0.677289
# Name: T_degC, dtype: float64

# %%
dataset.hist(figsize=(18,20), bins=10, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb6e8d63358>,
# ...
#       dtype=object)

# %%
corr = dataset.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, cbar = True, square = True, fmt = '.1f', annot = True, annot_kws = {'size' : 15}, cmap = 'Greens')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Depthm               864863 non-null  int64
#  1   T_degC               864863 non-null  float64
#  2   Salnty               864863 non-null  float64
#  3   STheta               864863 non-null  float64
#  4   RecInd               864863 non-null  int64
#  5   T_prec               864863 non-null  float64
#  6   S_prec               864863 non-null  float64
#  7   P_qual               673755 non-null  float64
#  8   IncTim               14437 non-null   object
#  9   R_Depth              864863 non-null  float64
#  10  R_TEMP               864863 non-null  float64
#  11  R_POTEMP             864863 non-null  float64
#  12  R_SALINITY           864863 non-null  float64
#  13  R_SIGMA              864863 non-null  float64
# ...

# %% [markdown]
# **Machine Learning**

# %%
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
label = dataset['T_degC']
features = dataset.drop(['T_degC'], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler, PowerTransformer, QuantileTransformer, MinMaxScaler, RobustScaler, MaxAbsScaler
pre_proc = [StandardScaler(), PowerTransformer(method='yeo-johnson', standardize = True), QuantileTransformer(), MinMaxScaler(), MaxAbsScaler(), RobustScaler()]

for proc in pre_proc : 
  scaler = proc
  features_scaled = scaler.fit_transform(features.values)
  label_scaled = scaler.fit_transform(label.values.reshape(-1,1)).flatten()

  from sklearn.model_selection import train_test_split
  feature_train, feature_test, label_train, label_test = train_test_split(features_scaled, label_scaled, test_size=0.2, random_state=10)

  linear_reg = LinearRegression()

  linear_reg.fit(feature_train, label_train)
  predictions = linear_reg.predict(feature_test)
  
  mse = round(mean_squared_error(label_test, predictions),10)
  mae = round(mean_absolute_error(label_test, predictions),10)
  r2 = round(r2_score(label_test, predictions),10)
  rmse = round(np.sqrt(mean_squared_error(label_test, predictions)),10)

  text = str(proc)
  text1 = text.split('(')[0]


  print(f"Preprocessing dengan model      -> {text1}")
  print(f"MSE (Mean Squared Error)        : {mse}")
  print(f"MAE (Mean Absolute Error)       : {mae}")
  print(f"r^2 score                       : {r2}")
  print(f'RMSE (Root Mean Squared Error)  : {rmse}\n')
# Out:
# Preprocessing dengan model      -> StandardScaler
# MSE (Mean Squared Error)        : 6.75e-08
# MAE (Mean Absolute Error)       : 2.85752e-05
# r^2 score                       : 0.9999999328
# RMSE (Root Mean Squared Error)  : 0.0002597224
#
# Preprocessing dengan model      -> PowerTransformer
# MSE (Mean Squared Error)        : 1.97e-08
# MAE (Mean Absolute Error)       : 2.85971e-05
# r^2 score                       : 0.9999999804
# RMSE (Root Mean Squared Error)  : 0.0001402383
#
# Preprocessing dengan model      -> QuantileTransformer
# MSE (Mean Squared Error)        : 1.2733e-06
# MAE (Mean Absolute Error)       : 0.0009128067
# r^2 score                       : 0.9999847373
# RMSE (Root Mean Squared Error)  : 0.0011284069
#
# Preprocessing dengan model      -> MinMaxScaler
# MSE (Mean Squared Error)        : 1.4e-09
# MAE (Mean Absolute Error)       : 4.0571e-06
# r^2 score                       : 0.9999999328
# RMSE (Root Mean Squared Error)  : 3.68757e-05
#
# ...

# %% [markdown]
# **Dari hasil diatas, didapatkan model Power Transformer merupakan model yang terbaik untuk kasus ini.**

# %%
from sklearn import preprocessing
# scaler = preprocessing.PowerTransformer(method='yeo-johnson')
scaler = preprocessing.QuantileTransformer(n_quantiles=1000)

features_scaled = scaler.fit_transform(features.values)
label_scaled = scaler.fit_transform(label.values.reshape(-1,1)).flatten()

from sklearn.model_selection import train_test_split
feature_train, feature_test, label_train, label_test = train_test_split(features_scaled, label_scaled, test_size=0.2, random_state=10)

# %%
forest_reg = RandomForestRegressor(n_estimators=52, random_state=5, max_features='sqrt')
forest_reg.fit(feature_train, label_train)
predictions = forest_reg.predict(feature_test)
print(f"r^2 score Random Forest Regressor                       : {r2_score(label_test, predictions)}")
print(f'RMSE (Root Mean Squared Error) Random Forest Regressor  : {np.sqrt(mean_squared_error(label_test, predictions))}\n')
# Out:
# r^2 score Random Forest Regressor                       : 0.999992251534825
# RMSE (Root Mean Squared Error) Random Forest Regressor  : 0.0008018925081437425

# %%
kernel = ['linear', 'poly', 'rbf']

for i in kernel :
  print("SVR, dengan n_estimators = ",i)
  svr_reg = SVR(kernel = i,C=1.0, epsilon=0.2)
  svr_reg.fit(feature_train, label_train)
  predictions = svr_reg.predict(feature_test)
  print(f"r^2 score SVR                      : {r2_score(label_test, predictions)}")
  print(f'RMSE (Root Mean Squared Error) SVR : {np.sqrt(mean_squared_error(label_test, predictions))}\n')
# Out:
# SVR, dengan n_estimators =  linear
# r^2 score SVR                      : 0.864771544611549
# RMSE (Root Mean Squared Error) SVR : 0.1059357039845445
#
# SVR, dengan n_estimators =  poly
# r^2 score SVR                      : 0.926402096960674
# RMSE (Root Mean Squared Error) SVR : 0.07815216860479604
#
# SVR, dengan n_estimators =  rbf
# r^2 score SVR                      : 0.939473673910829
# RMSE (Root Mean Squared Error) SVR : 0.07087294344063197

# %%
knn_reg = KNeighborsRegressor(n_neighbors= 7, leaf_size = 25)
knn_reg.fit(feature_train, label_train)
predictions = knn_reg.predict(feature_test)
print(f"r^2 score KNN Regressor                       : {r2_score(label_test, predictions)}")
print(f'RMSE (Root Mean Squared Error) KNN Regressor  : {np.sqrt(mean_squared_error(label_test, predictions))}\n')
# Out:
# r^2 score KNN Regressor                       : 0.999828519512428
# RMSE (Root Mean Squared Error) KNN Regressor  : 0.003772382036172456

# %%
xg_reg = xgb.XGBRegressor(booster='dart', learning_rate=1, max_depth=12, n_estimators=16)
xg_reg.fit(feature_train, label_train)
predictions = xg_reg.predict(feature_test)
print(f"r^2 score XGBRegressor                       : {r2_score(label_test, predictions)}")
print(f'RMSE (Root Mean Squared Error) XGBRegressor  : {np.sqrt(mean_squared_error(label_test, predictions))}\n')
# Out:
# [08:43:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r^2 score XGBRegressor                       : 0.9999989109976086
# RMSE (Root Mean Squared Error) XGBRegressor  : 0.00030062336380102937

# %% [markdown]
# **Kesimpulannya :**

# %% [markdown]
# Berdasarkan pengujian diatas, didapatkan r2 terbesar adalah 0.9999989 dengan RMSE yaitu 0.0003 dengan Algoritma XGBoost Regressor. Dapat disimpulkan bahwa data tersebut tidak memiliki indikasi overkilling dan memiliki akurasi yang sangat baik.
